# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# Dataset contains 11 indpendent and 1 dependent variable 
# there are no Nulls present in dataset

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
# As mean and median are almost having same value data will be symmetical and evenly distributed 
# But there may be some utliers present which we will rule our by plotting a Box plot

# %%
# Region is the only column which seems to have discrete value others are continous data only 
df.Region.unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df.Region.value_counts()
# Out:
# Region
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64

# %%
# above we can see he division of Data according to Region sub-saharan Africa has maximum values then Central and eastern europe

# %%
df1 = df.drop(columns = ['Region','Country'])
df1
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
fig,ax = plt.subplots(3,3,figsize=(12,12))
row = col = 0
for n,i in enumerate(df1):
    if (n%3 == 0) & (n > 0):
        row += 1
        col = 0
    df[i].plot(kind="box",ax=ax[row,col])
    col += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 7
#       5     row += 1
#       6     col = 0
# ----> 7 df[i].plot(kind="box",ax=ax[row,col])
#       8 col += 1
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
# There are few outliers present in standard error , Trust , Generosity , Dystopia Residual

# %%
df_corr = df1.corr()
df_corr


plt.figure(figsize=(14,8))
sns.heatmap(df_corr,annot=True,annot_kws={'size':10})
plt.show()

# %%
# no multicollinearity seen 
# as our region column is a categorical data we need to encode it using label encoder

# %%
encoder=LabelEncoder()
df['Region']=encoder.fit_transform(df['Region'])

# %%
df.head()
# Out:
#        Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0  Switzerland       9               1            7.587         0.03411
# 1      Iceland       9               2            7.561         0.04884
# 2      Denmark       9               3            7.527         0.03328
# 3       Norway       9               4            7.522         0.03880
# 4       Canada       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
x = df.drop(columns=['Country','Happiness Score'])

# %%
y = df['Happiness Score']

# %%
x
# Out:
#      Region  Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# 0         9               1         0.03411                   1.39651
# 1         9               2         0.04884                   1.30232
# 2         9               3         0.03328                   1.32548
# 3         9               4         0.03880                   1.45900
# 4         5               5         0.03553                   1.32629
# ..      ...             ...             ...                       ...
# 153       8             154         0.03464                   0.22208
# 154       8             155         0.03656                   0.28665
# 155       4             156         0.05015                   0.66320
# 156       8             157         0.08658                   0.01530
# 157       8             158         0.06727                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# ...

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x
# Out:
#      Region  Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# 0         9               1         0.03411                   1.39651
# 1         9               2         0.04884                   1.30232
# 2         9               3         0.03328                   1.32548
# 3         9               4         0.03880                   1.45900
# 4         5               5         0.03553                   1.32629
# ..      ...             ...             ...                       ...
# 153       8             154         0.03464                   0.22208
# 154       8             155         0.03656                   0.28665
# 155       4             156         0.05015                   0.66320
# 156       8             157         0.08658                   0.01530
# 157       8             158         0.06727                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.25,random_state=348)
y_train.head()
# Out:
# 48    5.960
# 76    5.286
# 90    5.057
# 44    5.995
# 56    5.828
# Name: Happiness Score, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(x_test)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.00025372154974071524

# %%
#training score
regression.score(x_train,y_train)
# Out:
# 0.9999999490440303

# %%
# testing score 
regression.score(x_test,y_pred)
# Out:
# 1.0

# %%
regression.predict(scaler.transform([[9,1,0.03411,1.39651,1.34951,0.94143,0.66557,0.41978,0.9678,2.51738]]))
# Out:
# array([8.25782985])
